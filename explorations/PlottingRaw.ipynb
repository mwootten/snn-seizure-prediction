# %%
import numpy as np

# %%
thousand_samples = np.fromfile('average.raw32', dtype=np.dtype('i4'), count=1000)

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 1000, 1)
y = thousand_samples

# %%
plt.plot(x, y)
plt.show()
