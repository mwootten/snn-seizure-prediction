# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
errorTime = [4.5, 8.0, 0.0, 0.0, 8.0, 0.0, 8.0, 8.0, 8.0, 0.0, 8.0, 0.5, 8.0, 8.0, 8.0, 0.5, 12.5, 8.0, 8.0, 12.5, 12.5, 12.5, 8.0, 8.0, 8.0, 12.5, 18.0, 4.5, 12.5, 12.5, 4.5, 0.5, 0.5, 4.5, 0.5, 12.5, 12.5, 12.5, 24.5, 24.5, 2.0, 18.0, 18.0, 24.5, 2.0, 2.0, 18.0, 24.5, 18.0, 2.0, 2.0, 24.5, 32.0, 0.0, 32.0, 2.0, 2.0, 32.0, 32.0, 32.0, 32.0, 0.0, 32.0, 32.0, 2.0, 2.0, 2.0, 2.0, 32.0, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 32.0, 0.5, 2.0, 40.5]

# %%
len(errorTime)
# Out:
# 81

# %%
x = range(81)
y = errorTime
plt.plot(x, y)
plt.show()

# %% [markdown]
# This looks like it's getting worse...

# %%
errorTime = [4.5, 4.5, 4.5, 0.5, 0.5, 4.5, 12.5, 12.5, 4.5, 0.5, 4.5, 12.5, 4.5, 12.5, 12.5, 4.5, 4.5, 0.5, 0.5, 4.5, 0.5, 4.5, 4.5, 4.5, 0.5, 12.5, 0.5, 4.5, 4.5, 12.5, 12.5, 4.5, 4.5, 12.5, 4.5, 4.5, 4.5, 4.5, 0.5, 4.5, 0.5, 12.5, 4.5, 0.5, 12.5, 4.5, 4.5, 0.5, 4.5, 4.5, 4.5, 12.5, 0.5, 0.5, 4.5, 4.5, 4.5, 0.5, 4.5, 4.5, 12.5, 4.5, 12.5, 4.5, 0.5, 4.5, 12.5, 4.5, 4.5, 12.5, 0.5, 0.5, 0.5, 0.5, 12.5, 12.5, 12.5, 4.5, 4.5, 0.5, 4.5, 4.5, 4.5, 4.5, 4.5, 0.5, 4.5, 12.5, 4.5, 4.5, 4.5, 0.5, 4.5, 0.5, 0.5, 4.5, 4.5, 0.5, 0.5, 12.5, 12.5]

# %%
x = range(101)
y = errorTime
plt.plot(x, y)
plt.show()
